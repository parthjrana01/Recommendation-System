# %% [markdown]
# # books recommendation system using clustering | collaborative technique

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('C:\\Users\\HP\\OneDrive\\Desktop\\Projects\\ML\\book recommendation system\\data\\Books.csv', sep=",", error_bad_lines=False, encoding='latin-1')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19376\2219082342.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   books = pd.read_csv('C:\\Users\\HP\\OneDrive\\Desktop\\Projects\\ML\\book recommendation system\\data\\Books.csv', sep=",", error_bad_lines=False, encoding='latin-1')
# C:\Users\HP\AppData\Local\Temp\ipykernel_19376\2219082342.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('C:\\Users\\HP\\OneDrive\\Desktop\\Projects\\ML\\book recommendation system\\data\\Books.csv', sep=",", error_bad_lines=False, encoding='latin-1')

# %%
books.head(5)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher','Image-URL-L']]

# %%
books.head(5)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.rename(columns={
    "Book-Title":"title",
    "Book-Author":"author",
    "Year-Of-Publication":"year",
    "Publisher":"publisher",
    "Image-URL-L":"img_url",
},inplace=True)

# %%
books.head(5)
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                              img_url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
# for users
users = pd.read_csv('C:\\Users\\HP\\OneDrive\\Desktop\\Projects\\ML\\book recommendation system\\data\\Users.csv', sep=",", error_bad_lines=False, encoding='latin-1')
users.head(2)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19376\2893293509.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   users = pd.read_csv('C:\\Users\\HP\\OneDrive\\Desktop\\Projects\\ML\\book recommendation system\\data\\Users.csv', sep=",", error_bad_lines=False, encoding='latin-1')
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings = pd.read_csv('C:\\Users\\HP\\OneDrive\\Desktop\\Projects\\ML\\book recommendation system\\data\\Ratings.csv', sep=",", error_bad_lines=False, encoding='latin-1')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19376\3448748025.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ratings = pd.read_csv('C:\\Users\\HP\\OneDrive\\Desktop\\Projects\\ML\\book recommendation system\\data\\Ratings.csv', sep=",", error_bad_lines=False, encoding='latin-1')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
ratings.rename(columns={
    "User-ID":"user_id",
    "Book-Rating":"rating"
}, inplace=True)

# %%
ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
ratings['user_id'].value_counts()
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: user_id, Length: 105283, dtype: int64

# %%
ratings['user_id'].unique().shape
# Out:
# (105283,)

# %%
x = ratings['user_id'].value_counts() > 200

# %%
x[x].shape
# Out:
# (899,)

# %%
y = x[x].index
print(y)
# Out:
# Int64Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352,
#             110973, 235105,
#             ...
#             260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727,
#             268622, 188951],
#            dtype='int64', length=899)

# %%
ratings[ratings['user_id'].isin(y)]
# Out:
#          user_id        ISBN  rating
# 1456      277427  002542730X      10
# 1457      277427  0026217457       0
# 1458      277427  003008685X       8
# 1459      277427  0030615321       0
# 1460      277427  0060002050       0
# ...          ...         ...     ...
# 1147612   275970  3829021860       0
# 1147613   275970  4770019572       0
# 1147614   275970   896086097       0
# 1147615   275970  9626340762       8
# 1147616   275970  9626344990       0
#
# [526356 rows x 3 columns]

# %%
ratings_with_books = ratings.merge(books,on="ISBN")

# %%
ratings_with_books
# Out:
#          user_id        ISBN  rating  \
# 0         276725  034545104X       0
# 1           2313  034545104X       5
# 2           6543  034545104X       0
# 3           8680  034545104X       5
# 4          10314  034545104X       9
# ...          ...         ...     ...
# 1031131   276688  0517145553       0
# 1031132   276688  1575660792       7
# 1031133   276690  0590907301       0
# 1031134   276704  0679752714       0
# 1031135   276704  0806917695       5
#
#                                                      title           author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# 4                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
num_rating = ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
print(num_rating.head())
# Out:
#                                                title  rating
# 0   A Light in the Storm: The Civil War Diary of ...       4
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...       1
# 4   Beyond IBM: Leadership Marketing and Finance ...       1

# %%
num_rating.rename(columns={
    "rating":"num_of_rating"
},inplace=True)

# %%
num_rating.head()
# Out:
#                                                title  num_of_rating
# 0   A Light in the Storm: The Civil War Diary of ...              4
# 1                              Always Have Popsicles              1
# 2               Apple Magic (The Collector's series)              1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...              1
# 4   Beyond IBM: Leadership Marketing and Finance ...              1

# %%
final_rating = ratings_with_books.merge(num_rating, on='title')

# %%
final_rating.head()
# Out:
#    user_id        ISBN  rating                 title      author  year  \
# 0   276725  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 1     2313  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 2     6543  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 3     8680  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 4    10314  034545104X       9  Flesh Tones: A Novel  M. J. Rose  2002
#
#           publisher                                            img_url  \
# 0  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 1  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 2  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 3  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 4  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
#
#    num_of_rating
# 0             60
# 1             60
# 2             60
# 3             60
# 4             60

# %%
final_rating.shape
# Out:
# (1031136, 9)

# %%
final_rating = final_rating[final_rating['num_of_rating']>=50]

# %%
final_rating.head()
# Out:
#    user_id        ISBN  rating                 title      author  year  \
# 0   276725  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 1     2313  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 2     6543  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 3     8680  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 4    10314  034545104X       9  Flesh Tones: A Novel  M. J. Rose  2002
#
#           publisher                                            img_url  \
# 0  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 1  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 2  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 3  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 4  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
#
#    num_of_rating
# 0             60
# 1             60
# 2             60
# 3             60
# 4             60

# %%
final_rating.sample(10)
# Out:
#         user_id        ISBN  rating                               title  \
# 110833    81045  0452269652       0   Jazz (Plume Contemporary Fiction)
# 309015   242824  0515114693       0                        Born in Fire
# 46609    238120  0375703861       0                White Teeth: A Novel
# 149484   221001  0312978367       6            The Prometheus Deception
# 323812    51811  0446365505       0                     Pleading Guilty
# 494390    43246  044990864X       0                     Black Lightning
# 98077     32721  1400031346       0  The No. 1 Ladies' Detective Agency
# 323938     5815  0451203895       5                           4 Blondes
# 128880    82893  0345378490       0                               Congo
# 58616     82628  0061030430       7                    Long Time No See
#
#                         author  year           publisher  \
# 110833           Toni Morrison  1993         Plume Books
# 309015            Nora Roberts  1994          Jove Books
# ...

# %%
final_rating.shape
# Out:
# (288740, 9)

# %%
final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
final_rating.shape
# Out:
# (285518, 9)

# %% [markdown]
# #  pivot table part

# %%
book_pivot = final_rating.pivot_table(columns='user_id',index='title',values='rating')

# %%
book_pivot
# Out:
# user_id                                             8       9       14      \
# title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# stardust                                               NaN     NaN     NaN
#
# ...

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# user_id                                             8       9       14      \
# title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <2444x47994 sparse matrix of type '<class 'numpy.float64'>'
# 	with 113444 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[257,:].values.reshape(1,-1),n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 48.78524367, 49.60846702, 49.75942122, 49.87985565,
#         50.12983144]])

# %%
suggestion
# Out:
# array([[ 257,  770, 2301,   65, 1713, 1391]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Black Friday', 'Ground Zero and Beyond', 'Treasures',
#        'A Secret Affair', 'The Blooding', 'Reasonable Doubt'],
#       dtype='object', name='title')

# %%
book_pivot.index[3]
# Out:
# '1st to Die: A Novel'

# %%
books_name = book_pivot.index

# %%
books_name
# Out:
# Index(['10 Lb. Penalty', '16 Lighthouse Road', '1984', '1st to Die: A Novel',
#        '2010: Odyssey Two', '204 Rosewood Lane', '2061: Odyssey Three',
#        '24 Hours', '2nd Chance', '3rd Degree',
#        ...
#        'YOU BELONG TO ME', 'Year of Wonders', 'You Belong To Me',
#        'You Shall Know Our Velocity', 'Young Wives',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"',
#        '\Surely You're Joking, Mr. Feynman!\": Adventures of a Curious Character"',
#        'stardust'],
#       dtype='object', name='title', length=2444)

# %%
import pickle
pickle.dump(model,open('C:/Users/HP/OneDrive/Desktop/Projects/ML/book recommendation system/artifacts/model.pkl', 'wb'))
pickle.dump(books_name,open('C:/Users/HP/OneDrive/Desktop/Projects/ML/book recommendation system/artifacts/books_name.pkl', 'wb'))
pickle.dump(final_rating,open('C:/Users/HP/OneDrive/Desktop/Projects/ML/book recommendation system/artifacts/final_rating.pkl', 'wb'))
pickle.dump(book_pivot,open('C:/Users/HP/OneDrive/Desktop/Projects/ML/book recommendation system/artifacts/book_pivot.pkl', 'wb'))

# %% [markdown]
# # Testing

# %%
def recommend_book(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1),n_neighbors=6)
    
    for i in range(len(suggestion)):
        books = book_pivot.index[suggestion[i]]
        for j in books:
            print(j)

# %%
book_name = '1st to Die: A Novel'
recommend_book(book_name)
# Out:
# 1st to Die: A Novel
# Now and Forever
# A Secret Affair
# Special Delivery: A Novel
# Women in His Life
# Creed for the Third Millennium
